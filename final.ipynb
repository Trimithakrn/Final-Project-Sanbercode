# %%
import pandas as pd
data = pd.read_csv('Data_Negara_HELP.csv')
data
# Out:
#                   Negara  Kematian_anak  Ekspor  Kesehatan  Impor  Pendapatan  \
# 0            Afghanistan           90.2    10.0       7.58   44.9        1610
# 1                Albania           16.6    28.0       6.55   48.6        9930
# 2                Algeria           27.3    38.4       4.17   31.4       12900
# 3                 Angola          119.0    62.3       2.85   42.9        5900
# 4    Antigua and Barbuda           10.3    45.5       6.03   58.9       19100
# ..                   ...            ...     ...        ...    ...         ...
# 162              Vanuatu           29.2    46.6       5.25   52.7        2950
# 163            Venezuela           17.1    28.5       4.91   17.6       16500
# 164              Vietnam           23.3    72.0       6.84   80.2        4490
# 165                Yemen           56.3    30.0       5.18   34.4        4480
# 166               Zambia           83.1    37.0       5.89   30.9        3280
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Negara            167 non-null    object
#  1   Kematian_anak     167 non-null    float64
#  2   Ekspor            167 non-null    float64
#  3   Kesehatan         167 non-null    float64
#  4   Impor             167 non-null    float64
#  5   Pendapatan        167 non-null    int64
#  6   Inflasi           167 non-null    float64
#  7   Harapan_hidup     167 non-null    float64
#  8   Jumlah_fertiliti  167 non-null    float64
#  9   GDPperkapita      167 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 13.2+ KB

# %%
print(data.isnull().sum())
# Out:
# Negara              0
# Kematian_anak       0
# Ekspor              0
# Kesehatan           0
# Impor               0
# Pendapatan          0
# Inflasi             0
# Harapan_hidup       0
# Jumlah_fertiliti    0
# GDPperkapita        0
# dtype: int64

# %%
data.describe()
# Out:
#        Kematian_anak      Ekspor   Kesehatan       Impor     Pendapatan  \
# count     167.000000  167.000000  167.000000  167.000000     167.000000
# mean       38.270060   41.108976    6.815689   46.890215   17144.688623
# std        40.328931   27.412010    2.746837   24.209589   19278.067698
# min         2.600000    0.109000    1.810000    0.065900     609.000000
# 25%         8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%        19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%        62.100000   51.350000    8.600000   58.750000   22800.000000
# max       208.000000  200.000000   17.900000  174.000000  125000.000000
#
#           Inflasi  Harapan_hidup  Jumlah_fertiliti   GDPperkapita
# count  167.000000     167.000000        167.000000     167.000000
# mean     7.781832      70.555689          2.947964   12964.155689
# std     10.570704       8.893172          1.513848   18328.704809
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Histogram
plt.figure(figsize=(10, 6))
plt.title('Histogram of GDP per kapita')
sns.histplot(data['GDPperkapita'], kde=True, color='skyblue')
plt.xlabel('GDP per kapita')
plt.ylabel('Frequency')
plt.show()

# Box plot
plt.figure(figsize=(8, 6))
plt.title('Boxplot of Kematian Anak')
sns.boxplot(y=data['Kematian_anak'], color='lightblue')
plt.ylabel('Kematian Anak')
plt.show()

# %%
X = data.loc[:, "Kematian_anak":]  # independent variables data
y = data['GDPperkapita']  # dependent variable data
data
# Out:
#                   Negara  Kematian_anak  Ekspor  Kesehatan  Impor  Pendapatan  \
# 0            Afghanistan           90.2    10.0       7.58   44.9        1610
# 1                Albania           16.6    28.0       6.55   48.6        9930
# 2                Algeria           27.3    38.4       4.17   31.4       12900
# 3                 Angola          119.0    62.3       2.85   42.9        5900
# 4    Antigua and Barbuda           10.3    45.5       6.03   58.9       19100
# ..                   ...            ...     ...        ...    ...         ...
# 162              Vanuatu           29.2    46.6       5.25   52.7        2950
# 163            Venezuela           17.1    28.5       4.91   17.6       16500
# 164              Vietnam           23.3    72.0       6.84   80.2        4490
# 165                Yemen           56.3    30.0       5.18   34.4        4480
# 166               Zambia           83.1    37.0       5.89   30.9        3280
#
# ...

# %%
# Membuat scatter plot matrix
sns.set(style="ticks")
sns.pairplot(data, y_vars=["GDPperkapita"], x_vars=["Kematian_anak", "Ekspor",
             "Kesehatan", "Impor", "Pendapatan", "Inflasi", "Harapan_hidup", "Jumlah_fertiliti"])

# Menampilkan plot
plt.tight_layout()
plt.show()

# %%
# Mengurutkan data berdasarkan variabel 'GDPperkapita' dan 'Kematian_anak'
sorted_data = data.sort_values('GDPperkapita')

# Mengambil lima negara terbawah
bottom_5_countries = sorted_data.head(5)

# Membuat histogram untuk lima negara terbawah
plt.figure(figsize=(10, 6))
sns.barplot(x='Negara', y='GDPperkapita',
            data=bottom_5_countries, color='skyblue')
plt.title('GDP per kapita untuk Lima Negara Terbawah')
plt.xlabel('Negara')
plt.ylabel('GDP per kapita')
plt.show()

# %%
# Menghitung korelasi antar variabel
corr = data.corr()

# Membuat heatmap korelasi
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Heatmap Korelasi Antar Variabel')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2444\3802467639.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()

# %%
# Mendefinisikan batas atas dan batas bawah menggunakan metode IQR untuk setiap kolom numerik
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Menampilkan nilai outlier untuk setiap kolom
outliers = ((data < lower_bound) | (data > upper_bound)).sum()
print("Jumlah outlier pada setiap kolom:")
print(outliers)
# Out:
# Jumlah outlier pada setiap kolom:
# Ekspor               5
# GDPperkapita        25
# Harapan_hidup        3
# Impor                4
# Inflasi              5
# Jumlah_fertiliti     1
# Kematian_anak        4
# Kesehatan            2
# Negara               0
# Pendapatan           8
# dtype: int64
# C:\Users\User\AppData\Local\Temp\ipykernel_2444\355723494.py:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = data.quantile(0.25)
# C:\Users\User\AppData\Local\Temp\ipykernel_2444\355723494.py:3: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3 = data.quantile(0.75)
# ...

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
data = data[~((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR))).any(axis=1)]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2444\744758719.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = data.quantile(0.25)
# C:\Users\User\AppData\Local\Temp\ipykernel_2444\744758719.py:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3 = data.quantile(0.75)
# C:\Users\User\AppData\Local\Temp\ipykernel_2444\744758719.py:4: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
# ...

# %%
# Melakukan handling outlier menggunakan boxplot
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
data = data[~((data < (Q1 - 1.5 * IQR)) |
              (data > (Q3 + 1.5 * IQR))).any(axis=1)]

# Visualisasi boxplot setelah handling outlier
plt.figure(figsize=(10, 6))
data.boxplot(color=dict(boxes='b', whiskers='b', medians='b', caps='b'))
plt.title('Boxplot setelah Handling Outlier')
plt.grid(False)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2444\3375664226.py:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = data.quantile(0.25)
# C:\Users\User\AppData\Local\Temp\ipykernel_2444\3375664226.py:3: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3 = data.quantile(0.75)
# C:\Users\User\AppData\Local\Temp\ipykernel_2444\3375664226.py:5: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data = data[~((data < (Q1 - 1.5 * IQR)) |
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data.iloc[:,1:])
pd.DataFrame(data_scaled)
# Out:
#             0         1         2         3         4         5         6  \
# 0    1.494591 -1.422871  0.674740  0.016606 -1.093047  0.258299 -1.780616
# 1   -0.760247 -0.450759  0.184946  0.226188  0.164740 -0.563339  1.057276
# 2   -0.432438  0.110906 -0.946810 -0.748086  0.613734  1.363775  1.085514
# 3    2.376919  1.401656 -1.574507 -0.096682 -0.444500  2.409495 -1.229980
# 4   -0.953257  0.494351 -0.062328  0.809619  1.551028 -1.069601  1.127870
# ..        ...       ...       ...       ...       ...       ...       ...
# 107 -0.156711 -0.250936 -0.166944 -0.912353 -0.695453  1.430170 -0.001639
# 108 -0.374229  0.553757 -0.433240  0.458427 -0.890471 -0.873735 -0.820533
# 109 -0.554984  1.925516  0.322849  2.016132 -0.657659  0.699825  0.605472
# 110  0.456017 -0.342746 -0.466527 -0.578154 -0.659171  2.608680 -0.185184
# 111  1.277072  0.035297 -0.128902 -0.776408 -0.840583  1.015201 -2.373608
#
#             7         8
# 0    1.881339 -1.021616
# 1   -1.020063 -0.086701
# ...

# %%
from sklearn.cluster import KMeans
# Menentukan jumlah cluster dengan metode Elbow
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(data_scaled)
    wcss.append(kmeans.inertia_)
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# Menampilkan nilai dari setiap cluster
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(data_scaled)
    clusters = kmeans.labels_
    print(f'Cluster counts for {i} clusters:',
          pd.Series(clusters).value_counts().to_dict())
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster counts for 1 clusters: {0: 112}
# Cluster counts for 2 clusters: {1: 64, 0: 48}
# Cluster counts for 3 clusters: {2: 51, 1: 32, 0: 29}
# ...

# %%
# Melakukan klastering dengan jumlah cluster tertentu
kmeans = KMeans(n_clusters=2, init='k-means++', random_state=42)
clusters = kmeans.fit_predict(data_scaled)
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data['Cluster'] = clusters
data.to_csv('hasil_cluster.csv')

# %%
data
# Out:
#      Unnamed: 0               Negara  Kematian_anak  Ekspor  Kesehatan  Impor  \
# 0             0          Afghanistan           90.2    10.0       7.58   44.9
# 1             1              Albania           16.6    28.0       6.55   48.6
# 2             2              Algeria           27.3    38.4       4.17   31.4
# 3             3               Angola          119.0    62.3       2.85   42.9
# 4             4  Antigua and Barbuda           10.3    45.5       6.03   58.9
# ..          ...                  ...            ...     ...        ...    ...
# 107         161           Uzbekistan           36.3    31.7       5.81   28.5
# 108         162              Vanuatu           29.2    46.6       5.25   52.7
# 109         164              Vietnam           23.3    72.0       6.84   80.2
# 110         165                Yemen           56.3    30.0       5.18   34.4
# 111         166               Zambia           83.1    37.0       5.89   30.9
#
# ...

# %%
import matplotlib.pyplot as plt
# Visualisasi Elbow Method
plt.plot(range(1, 11), wcss)
plt.title('Metode Elbow')
plt.xlabel('Jumlah Clusters')
plt.ylabel('WCSS')  # Within cluster sum of squares
plt.show()

# %%
plt.scatter(data[data['Cluster'] == 0]['Pendapatan'],
            data[data['Cluster'] == 0]['Kesehatan'], s=100, c='red', label='Cluster 1')
plt.scatter(data[data['Cluster'] == 1]['Pendapatan'],
            data[data['Cluster'] == 1]['Kesehatan'], s=100, c='blue', label='Cluster 2')

# Menandai pusat klaster
plt.title('Hasil Klastering')
plt.xlabel('Pendapatan')
plt.ylabel('Kesehatan')
plt.legend()
plt.show()

# %%
plt.scatter(data[data['Cluster'] == 0]['Kematian_anak'],
            data[data['Cluster'] == 0]['Harapan_hidup'], s=100, c='red', label='Cluster 1')
plt.scatter(data[data['Cluster'] == 1]['Kematian_anak'],
            data[data['Cluster'] == 1]['Harapan_hidup'], s=100, c='blue', label='Cluster 2')

# Menandai pusat klaster
plt.title('Keshatan')
plt.xlabel('Kematian Anak')
plt.ylabel('Harapan Hidup')
plt.legend()
plt.show()

# %%
focus_countries = data[data['Cluster'] == 0].nlargest(5, 'GDPperkapita')[
    'Negara']
print("Lima negara dengan nilai cluster yang paling perlu menjadi fokus CEO:")
for country in focus_countries:
    print(country)
# Out:
# Lima negara dengan nilai cluster yang paling perlu menjadi fokus CEO:
# Gabon
# South Africa
# Namibia
# Iraq
# Angola
